# %%
import segmenter
from matplotlib import pyplot as plt
import cv2

# %load_ext autoreload
# %autoreload 2

# %%
image = segmenter.read_image('data/T35VME_20190604.tif')
segmented_image, edges = segmenter.segment(image)
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(20,10))
ax1.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#ax2.imshow(edges, cmap="gray")
ax2.imshow(segmented_image)

# %%
image = segmenter.read_image('data/T35VME_20200531.tif')
segmented_image, edges = segmenter.segment(image)
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(20,10))
ax1.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#ax2.imshow(edges, cmap="gray")
ax2.imshow(segmented_image)

# %%
image = segmenter.read_image('data/T35VME_20200628.tif')
segmented_image, edges = segmenter.segment(image)
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(20,10))
ax1.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#ax2.imshow(edges, cmap="gray")
ax2.imshow(segmented_image)

# %%
image = segmenter.read_image('data/T35VME_20200718.tif')
segmented_image, edges = segmenter.segment(image)
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(20,10))
ax1.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#ax2.imshow(edges, cmap="gray")
ax2.imshow(segmented_image)
