# %%
import segmenter
from matplotlib import pyplot as plt
import numpy as np


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
image1 = segmenter.read_image('data/10-11-2020/Ala2_T35VME_20200531T0930.tif')
image2 = segmenter.read_image('data/10-11-2020/Ala2_T35VME_20200628T0940.tif')
image3 = segmenter.read_image('data/10-11-2020/Ala2_T35VME_20200718T0940.tif')
images = [image1, image2, image3]

segments, edges = segmenter.segment(images)

plt.figure(figsize=(13,13))
plt.imshow(segments)

# %%
plt.figure(figsize=(10,10))
plt.imshow(image2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import ndvi_classifier as nc

# %%
ndvi = nc.calculate_ndvi(images)

# %%
plt.figure(figsize=(13,13))
plt.imshow(ndvi[0], cmap='gray')
