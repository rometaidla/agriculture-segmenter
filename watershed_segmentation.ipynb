# %%
import segmenter
from matplotlib import pyplot as plt
import cv2 as cv


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
image1 = segmenter.read_image('data/T35VME_20200531.tif')
image2 = segmenter.read_image('data/T35VME_20200628.tif')
image3 = segmenter.read_image('data/T35VME_20200718.tif')

segments, edges = segmenter.segment([image1, image2, image3])

f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey='all', figsize=(15,15))
ax1.imshow(segments)
ax2.imshow(cv.cvtColor(image1, cv.COLOR_BGR2RGB))
ax3.imshow(cv.cvtColor(image2, cv.COLOR_BGR2RGB))
ax4.imshow(cv.cvtColor(image3, cv.COLOR_BGR2RGB))
